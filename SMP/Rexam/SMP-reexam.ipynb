# %% [markdown]
# SMP re-exam August 2020
# ==

# %%
# Student number: 266265

# %%
from scipy.stats import binom
from scipy.stats import uniform
from scipy.stats import geom
from scipy.stats import hypergeom
from scipy.stats import poisson
from scipy.stats import nbinom
import pandas as pd
import sympy as sp
from sympy import *
sp.init_printing()
import matplotlib.pyplot as plt
import scipy.integrate as integrate
from scipy.misc import derivative
import math
from math import *
from IPython.display import display, Math, Latex
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from numpy import *
from scipy import stats

# %% [markdown]
# Feel free to add cells if you need to. The easiest way to convert to pdf is to save this notebook as .html (File-->Download as-->HTML) and then convert this html file to pdf.

# %% [markdown]
# Assignment 1 (20%)
# ==

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# # a)
# x = sp.Symbol('x')
# q = sp.Symbol('q')
# u = sp.Symbol('u')

# possitive_infnity = float('inf') 
# negative_infnity = float('-inf') 
# fx = (1/e**q)*e**x
# fx
# upper= 3
# lower=negative_infnity

# integral= sp.integrate(fx, (u,1, x))
# list = solve(2.71828182845905**(-q)*2.71828182845905**x*x - 2.71828182845905**(-q)*2.71828182845905**x -1,q)
# q=list[0]
# # q=  0.999999999999998*log(20000000000000.0**(-x)*54365636569181.0**x*(x - 1.0))
# print("q =", list[0])
# fx1 = (1/e**list[0])*e**x
# integral= sp.integrate(fx1, (u,1, x))
# print('the comulative function is')
# print(integral)
# x3= sp.integrate(fx1, (x,negative_infnity, -3))

# print('P(X<0) : ',x3)
# print('P(X>2 = 0 ) since it is defined like so ')

# mean = sp.integrate(x*fx,(x,lower,upper))
# print('E(X) = ',mean)
# var = sp.integrate(fx*x**2,(x,lower,upper))-mean**2
# # or
# var2 = sp.integrate(((x-mean)**2)*fx,(x,lower,upper))-mean**2

# print('Var(X) =' , var2,'or in the same way', var)

# %%
# b)

# %%
# c)

# %%
# d)

# %% [markdown]
# Assignment 2 (10%)
# ==

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# a)

# %%
# b)

# %%
# c)

# %% [markdown]
# Assignment 3 (15%)
# ==

# %%
# a)

# %%
# b)

# %%
# c)

# %% [markdown]
# Assignment 4 (20%)
# ==

# %%
# a)

# %%
# b)

# %%
# c)

# %%
# d)

# %%
# e)

# %%
# f)

# %% [markdown]
# Assignment 5 (15%)
# ==

# %%
# a)

# %%
# b)

# %%
# c)

# %% [markdown]
# Assignment 6 (10%)
# ==

# %%
# a)

# %%
# b)

# %% [markdown]
# Assignment 7 (10%)
# ==
